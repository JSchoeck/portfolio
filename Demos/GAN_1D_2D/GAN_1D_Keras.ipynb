# %% [markdown]
# # 1D Generative Adversarial Network in Keras
#
# Inspired by [Machine Learning Mastery](https://machinelearningmastery.com/how-to-develop-a-generative-adversarial-network-for-a-1-dimensional-function-from-scratch-in-keras/)
#
# ## Index
# 1. Selecting a One-Dimensional Function
# 2. Defining a Discriminator Model
# 3. Defining a Generator Model
# 4. Training the Generator Model
# 5. Evaluating the Performance of the GAN
# 6. Running the GAN
#
# ## GAN Theory
# - Generator component creates new, realistic data points (X and Y component)
# - Discriminator component classifies if data point is original or generated
# - Performance of discriminator is used to update model weights of both generator and discriminator

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.vis_utils import plot_model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 1. Select a One-Dimensional Function
# - f(x) = sin(x)
# - Plot sin(x) from -2pi to 2pi

# %%
def calculate(x):
    return math.sin(x)

inputs = [0, math.pi/6, math.pi/4, math.pi/3, math.pi/2, 2*math.pi/3, math.pi, 4*math.pi/3, 3*math.pi/2, 5*math.pi/3, 2*math.pi]
inputs.extend([-x for x in inputs[1:]])
inputs.sort()

outputs = [calculate(x) for x in inputs]

plt.plot(inputs, outputs)
plt.title('Original 1D function');

# %% [markdown]
# ### Generating random samples for f(x)

# %%
def generate_samples(n=100):
    '''Generates random samples for f(x) from -pi to +pi'''
    X1 = (np.random.rand(n) - 0.5) * 2 * math.pi
    X2 = np.array([calculate(x) for x in X1])
    X1 = X1.reshape(n, 1)
    X2 = X2.reshape(n, 1)
    return np.hstack((X1, X2))

samples = generate_samples()

plt.scatter(samples[:, 0], samples[:, 1])
plt.title('Generated 1D function');

# %% [markdown]
# ## 2. Define a Discriminator Model
# - Binary classifier
# - In: sample with two real values
# - Out: likelyhood sample is original, not generated

# %%
def define_discriminator(n_inputs=2):
    model = Sequential()
    model.add(Dense(25, activation='relu', kernel_initializer='he_uniform', input_dim=n_inputs))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
model = define_discriminator()
model.summary()
plot_model(model, to_file='GAN_1D_Keras_discriminator_plot.png', show_shapes=True, show_layer_names=True);
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 25)                75
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Discriminator Model Plot
# ![Discriminator Model](GAN_1D_Keras_discriminator_plot.png 'Discriminator Model')

# %% [markdown]
# ### Generate real and fake samples
# - generate_real_samples creates real samples, where X2 = f(X1)
# - generate_fake_samples creates fake samples, where X2 is independently created from X1
# - Classification labels are added to each generated value (0 = fake, 1 = real)

# %%
def generate_real_samples(n=100):
    '''Generates random samples for f(x) from -pi to +pi'''
    X1 = (np.random.rand(n) - 0.5) * 2 * math.pi
    X2 = np.array([calculate(x) for x in X1])
    X1 = X1.reshape(n, 1)
    X2 = X2.reshape(n, 1)
    X = np.hstack((X1, X2))
    y = np.ones((n, 1))
    return X, y

def generate_fake_samples(n=100):
    '''Generates random samples from -pi to +pi that are not using f(x) for X2'''
    X1 = (np.random.rand(n) - 0.5) * 2 * math.pi    
    X2 = (np.random.rand(n) - 0.5) * 2 * math.pi
    X1 = X1.reshape(n, 1)
    X2 = X2.reshape(n, 1)
    X = np.hstack((X1, X2))
    y = np.zeros((n, 1))
    return X, y

# %%
fake_samples, y = generate_fake_samples()
plt.scatter(fake_samples[:, 0], fake_samples[:, 1])
plt.title('Generated 1D function of fake samples');

# %% [markdown]
# ### Train discriminator
# - Update the model with generated data during training
# - Generate 50% fake and 50% real samples for each training epoch

# %%
def train_discriminator(model, n_epochs=1000, n_batch=128):
    '''Manually run epochs for training with generated data'''
    half_batch = int(n_batch/2)
    epoch_hist_real = []
    epoch_hist_fake = []
    for i in range(0, n_epochs):
        X_real, y_real = generate_real_samples(half_batch)
        epoch_hist_real.append(model.train_on_batch(X_real, y_real))
        X_fake, y_fake = generate_fake_samples(half_batch)
        epoch_hist_fake.append(model.train_on_batch(X_fake, y_fake))
        _, acc_real = model.evaluate(X_real, y_real, verbose=0)
        _, acc_fake = model.evaluate(X_fake, y_fake, verbose=0)
        print('Epoch {}: acc_real = {}, acc_fake = {}'.format(i, acc_real, acc_fake))
    return epoch_hist_real, epoch_hist_fake

# %%
model = define_discriminator()
epoch_hist_real, epoch_hist_fake = train_discriminator(model)
# Out:
# Epoch 0: acc_real = 0.484375, acc_fake = 0.625
# Epoch 1: acc_real = 0.40625, acc_fake = 0.625
# Epoch 2: acc_real = 0.5625, acc_fake = 0.65625
# Epoch 3: acc_real = 0.40625, acc_fake = 0.65625
# Epoch 4: acc_real = 0.421875, acc_fake = 0.65625
# Epoch 5: acc_real = 0.453125, acc_fake = 0.703125
# Epoch 6: acc_real = 0.4375, acc_fake = 0.59375
# Epoch 7: acc_real = 0.5, acc_fake = 0.65625
# Epoch 8: acc_real = 0.515625, acc_fake = 0.75
# Epoch 9: acc_real = 0.515625, acc_fake = 0.78125
# Epoch 10: acc_real = 0.59375, acc_fake = 0.75
# Epoch 11: acc_real = 0.65625, acc_fake = 0.59375
# Epoch 12: acc_real = 0.5625, acc_fake = 0.6875
# Epoch 13: acc_real = 0.53125, acc_fake = 0.71875
# Epoch 14: acc_real = 0.640625, acc_fake = 0.625
# Epoch 15: acc_real = 0.484375, acc_fake = 0.75
# Epoch 16: acc_real = 0.484375, acc_fake = 0.703125
# Epoch 17: acc_real = 0.4375, acc_fake = 0.609375
# Epoch 18: acc_real = 0.59375, acc_fake = 0.765625
# Epoch 19: acc_real = 0.484375, acc_fake = 0.6875
# Epoch 20: acc_real = 0.46875, acc_fake = 0.6875
# Epoch 21: acc_real = 0.59375, acc_fake = 0.71875
# Epoch 22: acc_real = 0.640625, acc_fake = 0.765625
# Epoch 23: acc_real = 0.546875, acc_fake = 0.6875
# Epoch 24: acc_real = 0.5, acc_fake = 0.671875
# Epoch 25: acc_real = 0.546875, acc_fake = 0.734375
# Epoch 26: acc_real = 0.578125, acc_fake = 0.734375
# Epoch 27: acc_real = 0.640625, acc_fake = 0.71875
# Epoch 28: acc_real = 0.609375, acc_fake = 0.71875
# Epoch 29: acc_real = 0.609375, acc_fake = 0.671875
# Epoch 30: acc_real = 0.734375, acc_fake = 0.703125
# Epoch 31: acc_real = 0.671875, acc_fake = 0.765625
# Epoch 32: acc_real = 0.609375, acc_fake = 0.921875
# Epoch 33: acc_real = 0.640625, acc_fake = 0.734375
# Epoch 34: acc_real = 0.65625, acc_fake = 0.703125
# Epoch 35: acc_real = 0.8125, acc_fake = 0.6875
# Epoch 36: acc_real = 0.59375, acc_fake = 0.71875
# Epoch 37: acc_real = 0.671875, acc_fake = 0.734375
# Epoch 38: acc_real = 0.796875, acc_fake = 0.8125
# Epoch 39: acc_real = 0.75, acc_fake = 0.796875
# Epoch 40: acc_real = 0.5625, acc_fake = 0.78125
# Epoch 41: acc_real = 0.625, acc_fake = 0.65625
# Epoch 42: acc_real = 0.671875, acc_fake = 0.75
# Epoch 43: acc_real = 0.6875, acc_fake = 0.71875
# Epoch 44: acc_real = 0.65625, acc_fake = 0.703125
# Epoch 45: acc_real = 0.65625, acc_fake = 0.6875
# Epoch 46: acc_real = 0.6875, acc_fake = 0.578125
# Epoch 47: acc_real = 0.671875, acc_fake = 0.78125
# Epoch 48: acc_real = 0.71875, acc_fake = 0.75
# Epoch 49: acc_real = 0.5625, acc_fake = 0.578125
# Epoch 50: acc_real = 0.671875, acc_fake = 0.640625
# Epoch 51: acc_real = 0.671875, acc_fake = 0.71875
# Epoch 52: acc_real = 0.78125, acc_fake = 0.65625
# Epoch 53: acc_real = 0.6875, acc_fake = 0.703125
# Epoch 54: acc_real = 0.609375, acc_fake = 0.78125
# Epoch 55: acc_real = 0.796875, acc_fake = 0.65625
# Epoch 56: acc_real = 0.703125, acc_fake = 0.71875
# Epoch 57: acc_real = 0.703125, acc_fake = 0.625
# Epoch 58: acc_real = 0.703125, acc_fake = 0.703125
# Epoch 59: acc_real = 0.78125, acc_fake = 0.703125
# Epoch 60: acc_real = 0.65625, acc_fake = 0.703125
# Epoch 61: acc_real = 0.609375, acc_fake = 0.671875
# Epoch 62: acc_real = 0.609375, acc_fake = 0.75
# Epoch 63: acc_real = 0.78125, acc_fake = 0.71875
# Epoch 64: acc_real = 0.71875, acc_fake = 0.671875
# Epoch 65: acc_real = 0.671875, acc_fake = 0.734375
# Epoch 66: acc_real = 0.65625, acc_fake = 0.671875
# Epoch 67: acc_real = 0.640625, acc_fake = 0.578125
# Epoch 68: acc_real = 0.71875, acc_fake = 0.75
# Epoch 69: acc_real = 0.671875, acc_fake = 0.765625
# Epoch 70: acc_real = 0.671875, acc_fake = 0.765625
# Epoch 71: acc_real = 0.75, acc_fake = 0.75
# Epoch 72: acc_real = 0.65625, acc_fake = 0.765625
# Epoch 73: acc_real = 0.796875, acc_fake = 0.734375
# Epoch 74: acc_real = 0.640625, acc_fake = 0.625
# Epoch 75: acc_real = 0.671875, acc_fake = 0.734375
# Epoch 76: acc_real = 0.65625, acc_fake = 0.71875
# Epoch 77: acc_real = 0.71875, acc_fake = 0.625
# Epoch 78: acc_real = 0.734375, acc_fake = 0.625
# Epoch 79: acc_real = 0.53125, acc_fake = 0.71875
# Epoch 80: acc_real = 0.71875, acc_fake = 0.78125
# Epoch 81: acc_real = 0.71875, acc_fake = 0.734375
# Epoch 82: acc_real = 0.765625, acc_fake = 0.625
# Epoch 83: acc_real = 0.640625, acc_fake = 0.765625
# Epoch 84: acc_real = 0.703125, acc_fake = 0.703125
# Epoch 85: acc_real = 0.78125, acc_fake = 0.71875
# Epoch 86: acc_real = 0.625, acc_fake = 0.8125
# Epoch 87: acc_real = 0.703125, acc_fake = 0.84375
# Epoch 88: acc_real = 0.703125, acc_fake = 0.796875
# Epoch 89: acc_real = 0.6875, acc_fake = 0.765625
# Epoch 90: acc_real = 0.671875, acc_fake = 0.78125
# Epoch 91: acc_real = 0.609375, acc_fake = 0.75
# Epoch 92: acc_real = 0.65625, acc_fake = 0.671875
# Epoch 93: acc_real = 0.703125, acc_fake = 0.75
# Epoch 94: acc_real = 0.65625, acc_fake = 0.796875
# Epoch 95: acc_real = 0.6875, acc_fake = 0.765625
# Epoch 96: acc_real = 0.71875, acc_fake = 0.8125
# Epoch 97: acc_real = 0.5625, acc_fake = 0.71875
# Epoch 98: acc_real = 0.703125, acc_fake = 0.75
# Epoch 99: acc_real = 0.71875, acc_fake = 0.875
# Epoch 100: acc_real = 0.640625, acc_fake = 0.859375
# Epoch 101: acc_real = 0.6875, acc_fake = 0.828125
# Epoch 102: acc_real = 0.71875, acc_fake = 0.78125
# Epoch 103: acc_real = 0.734375, acc_fake = 0.71875
# Epoch 104: acc_real = 0.59375, acc_fake = 0.78125
# Epoch 105: acc_real = 0.671875, acc_fake = 0.71875
# Epoch 106: acc_real = 0.609375, acc_fake = 0.84375
# Epoch 107: acc_real = 0.703125, acc_fake = 0.765625
# Epoch 108: acc_real = 0.703125, acc_fake = 0.859375
# Epoch 109: acc_real = 0.71875, acc_fake = 0.796875
# Epoch 110: acc_real = 0.796875, acc_fake = 0.828125
# Epoch 111: acc_real = 0.6875, acc_fake = 0.796875
# Epoch 112: acc_real = 0.65625, acc_fake = 0.8125
# Epoch 113: acc_real = 0.671875, acc_fake = 0.84375
# Epoch 114: acc_real = 0.71875, acc_fake = 0.703125
# Epoch 115: acc_real = 0.671875, acc_fake = 0.8125
# Epoch 116: acc_real = 0.703125, acc_fake = 0.796875
# Epoch 117: acc_real = 0.640625, acc_fake = 0.78125
# Epoch 118: acc_real = 0.6875, acc_fake = 0.75
# Epoch 119: acc_real = 0.703125, acc_fake = 0.734375
# Epoch 120: acc_real = 0.78125, acc_fake = 0.8125
# Epoch 121: acc_real = 0.703125, acc_fake = 0.890625
# Epoch 122: acc_real = 0.78125, acc_fake = 0.75
# Epoch 123: acc_real = 0.71875, acc_fake = 0.859375
# Epoch 124: acc_real = 0.65625, acc_fake = 0.796875
# Epoch 125: acc_real = 0.703125, acc_fake = 0.796875
# Epoch 126: acc_real = 0.65625, acc_fake = 0.75
# Epoch 127: acc_real = 0.734375, acc_fake = 0.8125
# Epoch 128: acc_real = 0.671875, acc_fake = 0.875
# Epoch 129: acc_real = 0.734375, acc_fake = 0.734375
# Epoch 130: acc_real = 0.625, acc_fake = 0.828125
# Epoch 131: acc_real = 0.734375, acc_fake = 0.859375
# Epoch 132: acc_real = 0.75, acc_fake = 0.796875
# Epoch 133: acc_real = 0.671875, acc_fake = 0.84375
# Epoch 134: acc_real = 0.6875, acc_fake = 0.796875
# Epoch 135: acc_real = 0.75, acc_fake = 0.703125
# Epoch 136: acc_real = 0.796875, acc_fake = 0.84375
# Epoch 137: acc_real = 0.6875, acc_fake = 0.734375
# Epoch 138: acc_real = 0.75, acc_fake = 0.859375
# Epoch 139: acc_real = 0.671875, acc_fake = 0.78125
# Epoch 140: acc_real = 0.765625, acc_fake = 0.84375
# Epoch 141: acc_real = 0.65625, acc_fake = 0.734375
# Epoch 142: acc_real = 0.75, acc_fake = 0.796875
# Epoch 143: acc_real = 0.75, acc_fake = 0.78125
# Epoch 144: acc_real = 0.703125, acc_fake = 0.859375
# Epoch 145: acc_real = 0.71875, acc_fake = 0.84375
# Epoch 146: acc_real = 0.75, acc_fake = 0.84375
# Epoch 147: acc_real = 0.703125, acc_fake = 0.71875
# Epoch 148: acc_real = 0.71875, acc_fake = 0.796875
# Epoch 149: acc_real = 0.734375, acc_fake = 0.765625
# Epoch 150: acc_real = 0.671875, acc_fake = 0.859375
# Epoch 151: acc_real = 0.75, acc_fake = 0.828125
# Epoch 152: acc_real = 0.71875, acc_fake = 0.90625
# Epoch 153: acc_real = 0.78125, acc_fake = 0.890625
# Epoch 154: acc_real = 0.671875, acc_fake = 0.828125
# Epoch 155: acc_real = 0.78125, acc_fake = 0.859375
# Epoch 156: acc_real = 0.734375, acc_fake = 0.8125
# Epoch 157: acc_real = 0.765625, acc_fake = 0.890625
# Epoch 158: acc_real = 0.78125, acc_fake = 0.828125
# Epoch 159: acc_real = 0.75, acc_fake = 0.78125
# Epoch 160: acc_real = 0.796875, acc_fake = 0.78125
# Epoch 161: acc_real = 0.640625, acc_fake = 0.828125
# Epoch 162: acc_real = 0.78125, acc_fake = 0.828125
# Epoch 163: acc_real = 0.78125, acc_fake = 0.859375
# Epoch 164: acc_real = 0.71875, acc_fake = 0.8125
# Epoch 165: acc_real = 0.75, acc_fake = 0.796875
# Epoch 166: acc_real = 0.78125, acc_fake = 0.765625
# Epoch 167: acc_real = 0.765625, acc_fake = 0.84375
# Epoch 168: acc_real = 0.71875, acc_fake = 0.828125
# Epoch 169: acc_real = 0.71875, acc_fake = 0.796875
# Epoch 170: acc_real = 0.84375, acc_fake = 0.796875
# Epoch 171: acc_real = 0.734375, acc_fake = 0.75
# Epoch 172: acc_real = 0.75, acc_fake = 0.78125
# Epoch 173: acc_real = 0.78125, acc_fake = 0.796875
# Epoch 174: acc_real = 0.859375, acc_fake = 0.8125
# Epoch 175: acc_real = 0.8125, acc_fake = 0.796875
# Epoch 176: acc_real = 0.765625, acc_fake = 0.796875
# Epoch 177: acc_real = 0.84375, acc_fake = 0.9375
# Epoch 178: acc_real = 0.78125, acc_fake = 0.71875
# Epoch 179: acc_real = 0.78125, acc_fake = 0.75
# Epoch 180: acc_real = 0.78125, acc_fake = 0.875
# Epoch 181: acc_real = 0.6875, acc_fake = 0.796875
# Epoch 182: acc_real = 0.765625, acc_fake = 0.765625
# Epoch 183: acc_real = 0.796875, acc_fake = 0.765625
# Epoch 184: acc_real = 0.71875, acc_fake = 0.859375
# Epoch 185: acc_real = 0.828125, acc_fake = 0.90625
# Epoch 186: acc_real = 0.828125, acc_fake = 0.859375
# Epoch 187: acc_real = 0.828125, acc_fake = 0.78125
# Epoch 188: acc_real = 0.84375, acc_fake = 0.90625
# Epoch 189: acc_real = 0.84375, acc_fake = 0.828125
# Epoch 190: acc_real = 0.828125, acc_fake = 0.859375
# Epoch 191: acc_real = 0.890625, acc_fake = 0.8125
# Epoch 192: acc_real = 0.84375, acc_fake = 0.828125
# Epoch 193: acc_real = 0.828125, acc_fake = 0.84375
# Epoch 194: acc_real = 0.796875, acc_fake = 0.828125
# Epoch 195: acc_real = 0.875, acc_fake = 0.84375
# Epoch 196: acc_real = 0.828125, acc_fake = 0.671875
# Epoch 197: acc_real = 0.84375, acc_fake = 0.765625
# Epoch 198: acc_real = 0.890625, acc_fake = 0.796875
# Epoch 199: acc_real = 0.796875, acc_fake = 0.8125
# Epoch 200: acc_real = 0.8125, acc_fake = 0.734375
# Epoch 201: acc_real = 0.84375, acc_fake = 0.796875
# Epoch 202: acc_real = 0.84375, acc_fake = 0.75
# Epoch 203: acc_real = 0.859375, acc_fake = 0.765625
# Epoch 204: acc_real = 0.765625, acc_fake = 0.71875
# Epoch 205: acc_real = 0.796875, acc_fake = 0.859375
# Epoch 206: acc_real = 0.78125, acc_fake = 0.828125
# Epoch 207: acc_real = 0.84375, acc_fake = 0.796875
# Epoch 208: acc_real = 0.8125, acc_fake = 0.8125
# Epoch 209: acc_real = 0.75, acc_fake = 0.84375
# Epoch 210: acc_real = 0.828125, acc_fake = 0.875
# Epoch 211: acc_real = 0.765625, acc_fake = 0.890625
# Epoch 212: acc_real = 0.765625, acc_fake = 0.859375
# Epoch 213: acc_real = 0.78125, acc_fake = 0.890625
# Epoch 214: acc_real = 0.75, acc_fake = 0.84375
# Epoch 215: acc_real = 0.875, acc_fake = 0.78125
# Epoch 216: acc_real = 0.828125, acc_fake = 0.84375
# Epoch 217: acc_real = 0.796875, acc_fake = 0.875
# Epoch 218: acc_real = 0.875, acc_fake = 0.84375
# Epoch 219: acc_real = 0.859375, acc_fake = 0.84375
# Epoch 220: acc_real = 0.828125, acc_fake = 0.796875
# Epoch 221: acc_real = 0.859375, acc_fake = 0.859375
# Epoch 222: acc_real = 0.859375, acc_fake = 0.875
# Epoch 223: acc_real = 0.796875, acc_fake = 0.765625
# Epoch 224: acc_real = 0.859375, acc_fake = 0.828125
# Epoch 225: acc_real = 0.859375, acc_fake = 0.8125
# Epoch 226: acc_real = 0.796875, acc_fake = 0.84375
# Epoch 227: acc_real = 0.859375, acc_fake = 0.84375
# Epoch 228: acc_real = 0.796875, acc_fake = 0.796875
# Epoch 229: acc_real = 0.90625, acc_fake = 0.765625
# Epoch 230: acc_real = 0.90625, acc_fake = 0.84375
# Epoch 231: acc_real = 0.875, acc_fake = 0.765625
# Epoch 232: acc_real = 0.875, acc_fake = 0.890625
# Epoch 233: acc_real = 0.84375, acc_fake = 0.875
# Epoch 234: acc_real = 0.859375, acc_fake = 0.875
# Epoch 235: acc_real = 0.75, acc_fake = 0.90625
# Epoch 236: acc_real = 0.828125, acc_fake = 0.875
# Epoch 237: acc_real = 0.890625, acc_fake = 0.75
# Epoch 238: acc_real = 0.875, acc_fake = 0.796875
# Epoch 239: acc_real = 0.828125, acc_fake = 0.9375
# Epoch 240: acc_real = 0.859375, acc_fake = 0.75
# Epoch 241: acc_real = 0.828125, acc_fake = 0.828125
# Epoch 242: acc_real = 0.90625, acc_fake = 0.78125
# Epoch 243: acc_real = 0.828125, acc_fake = 0.8125
# Epoch 244: acc_real = 0.84375, acc_fake = 0.734375
# Epoch 245: acc_real = 0.890625, acc_fake = 0.90625
# Epoch 246: acc_real = 0.859375, acc_fake = 0.859375
# Epoch 247: acc_real = 0.890625, acc_fake = 0.8125
# Epoch 248: acc_real = 0.875, acc_fake = 0.796875
# Epoch 249: acc_real = 0.875, acc_fake = 0.890625
# Epoch 250: acc_real = 0.875, acc_fake = 0.8125
# Epoch 251: acc_real = 0.859375, acc_fake = 0.921875
# Epoch 252: acc_real = 0.859375, acc_fake = 0.90625
# Epoch 253: acc_real = 0.90625, acc_fake = 0.875
# Epoch 254: acc_real = 0.90625, acc_fake = 0.859375
# Epoch 255: acc_real = 0.9375, acc_fake = 0.859375
# Epoch 256: acc_real = 0.84375, acc_fake = 0.75
# Epoch 257: acc_real = 0.9375, acc_fake = 0.828125
# Epoch 258: acc_real = 0.859375, acc_fake = 0.796875
# Epoch 259: acc_real = 0.875, acc_fake = 0.890625
# Epoch 260: acc_real = 0.9375, acc_fake = 0.84375
# Epoch 261: acc_real = 0.9375, acc_fake = 0.859375
# Epoch 262: acc_real = 0.953125, acc_fake = 0.828125
# Epoch 263: acc_real = 0.890625, acc_fake = 0.859375
# Epoch 264: acc_real = 0.890625, acc_fake = 0.84375
# Epoch 265: acc_real = 0.859375, acc_fake = 0.859375
# Epoch 266: acc_real = 0.875, acc_fake = 0.8125
# Epoch 267: acc_real = 0.859375, acc_fake = 0.890625
# Epoch 268: acc_real = 0.890625, acc_fake = 0.765625
# Epoch 269: acc_real = 0.9375, acc_fake = 0.796875
# Epoch 270: acc_real = 0.890625, acc_fake = 0.796875
# Epoch 271: acc_real = 0.90625, acc_fake = 0.890625
# Epoch 272: acc_real = 0.890625, acc_fake = 0.84375
# Epoch 273: acc_real = 0.921875, acc_fake = 0.859375
# Epoch 274: acc_real = 0.875, acc_fake = 0.8125
# Epoch 275: acc_real = 0.921875, acc_fake = 0.875
# Epoch 276: acc_real = 0.921875, acc_fake = 0.8125
# Epoch 277: acc_real = 0.9375, acc_fake = 0.828125
# Epoch 278: acc_real = 0.921875, acc_fake = 0.84375
# Epoch 279: acc_real = 0.9375, acc_fake = 0.84375
# Epoch 280: acc_real = 0.953125, acc_fake = 0.859375
# Epoch 281: acc_real = 0.890625, acc_fake = 0.859375
# Epoch 282: acc_real = 0.953125, acc_fake = 0.84375
# Epoch 283: acc_real = 0.84375, acc_fake = 0.828125
# Epoch 284: acc_real = 0.90625, acc_fake = 0.828125
# Epoch 285: acc_real = 0.953125, acc_fake = 0.84375
# Epoch 286: acc_real = 0.921875, acc_fake = 0.8125
# Epoch 287: acc_real = 0.953125, acc_fake = 0.765625
# Epoch 288: acc_real = 0.921875, acc_fake = 0.875
# Epoch 289: acc_real = 0.9375, acc_fake = 0.890625
# Epoch 290: acc_real = 0.90625, acc_fake = 0.828125
# Epoch 291: acc_real = 0.9375, acc_fake = 0.8125
# Epoch 292: acc_real = 0.953125, acc_fake = 0.828125
# Epoch 293: acc_real = 0.90625, acc_fake = 0.8125
# Epoch 294: acc_real = 0.9375, acc_fake = 0.859375
# Epoch 295: acc_real = 0.890625, acc_fake = 0.828125
# Epoch 296: acc_real = 0.984375, acc_fake = 0.828125
# Epoch 297: acc_real = 0.921875, acc_fake = 0.90625
# Epoch 298: acc_real = 0.90625, acc_fake = 0.859375
# Epoch 299: acc_real = 0.90625, acc_fake = 0.828125
# Epoch 300: acc_real = 0.953125, acc_fake = 0.84375
# Epoch 301: acc_real = 1.0, acc_fake = 0.890625
# Epoch 302: acc_real = 0.890625, acc_fake = 0.8125
# Epoch 303: acc_real = 0.921875, acc_fake = 0.90625
# Epoch 304: acc_real = 0.921875, acc_fake = 0.8125
# Epoch 305: acc_real = 0.96875, acc_fake = 0.875
# Epoch 306: acc_real = 0.9375, acc_fake = 0.875
# Epoch 307: acc_real = 0.9375, acc_fake = 0.90625
# Epoch 308: acc_real = 0.984375, acc_fake = 0.921875
# Epoch 309: acc_real = 0.921875, acc_fake = 0.828125
# Epoch 310: acc_real = 0.890625, acc_fake = 0.84375
# Epoch 311: acc_real = 0.953125, acc_fake = 0.90625
# Epoch 312: acc_real = 0.984375, acc_fake = 0.84375
# Epoch 313: acc_real = 0.953125, acc_fake = 0.890625
# Epoch 314: acc_real = 0.96875, acc_fake = 0.859375
# Epoch 315: acc_real = 0.9375, acc_fake = 0.8125
# Epoch 316: acc_real = 0.96875, acc_fake = 0.875
# Epoch 317: acc_real = 0.859375, acc_fake = 0.9375
# Epoch 318: acc_real = 0.9375, acc_fake = 0.859375
# Epoch 319: acc_real = 0.921875, acc_fake = 0.828125
# Epoch 320: acc_real = 0.953125, acc_fake = 0.75
# Epoch 321: acc_real = 0.90625, acc_fake = 0.828125
# Epoch 322: acc_real = 0.96875, acc_fake = 0.875
# Epoch 323: acc_real = 0.953125, acc_fake = 0.859375
# Epoch 324: acc_real = 0.9375, acc_fake = 0.890625
# Epoch 325: acc_real = 0.96875, acc_fake = 0.9375
# Epoch 326: acc_real = 0.953125, acc_fake = 0.90625
# Epoch 327: acc_real = 0.9375, acc_fake = 0.84375
# Epoch 328: acc_real = 1.0, acc_fake = 0.84375
# Epoch 329: acc_real = 0.9375, acc_fake = 0.828125
# Epoch 330: acc_real = 0.90625, acc_fake = 0.90625
# Epoch 331: acc_real = 0.9375, acc_fake = 0.84375
# Epoch 332: acc_real = 0.9375, acc_fake = 0.796875
# Epoch 333: acc_real = 0.96875, acc_fake = 0.78125
# Epoch 334: acc_real = 1.0, acc_fake = 0.890625
# Epoch 335: acc_real = 0.96875, acc_fake = 0.921875
# Epoch 336: acc_real = 0.96875, acc_fake = 0.875
# Epoch 337: acc_real = 0.96875, acc_fake = 0.828125
# Epoch 338: acc_real = 0.9375, acc_fake = 0.8125
# Epoch 339: acc_real = 0.984375, acc_fake = 0.859375
# Epoch 340: acc_real = 0.96875, acc_fake = 0.78125
# Epoch 341: acc_real = 0.96875, acc_fake = 0.875
# Epoch 342: acc_real = 0.96875, acc_fake = 0.8125
# Epoch 343: acc_real = 0.984375, acc_fake = 0.90625
# Epoch 344: acc_real = 0.984375, acc_fake = 0.859375
# Epoch 345: acc_real = 0.984375, acc_fake = 0.75
# Epoch 346: acc_real = 0.921875, acc_fake = 0.859375
# Epoch 347: acc_real = 0.96875, acc_fake = 0.828125
# Epoch 348: acc_real = 0.96875, acc_fake = 0.734375
# Epoch 349: acc_real = 0.96875, acc_fake = 0.828125
# Epoch 350: acc_real = 0.96875, acc_fake = 0.78125
# Epoch 351: acc_real = 0.96875, acc_fake = 0.890625
# Epoch 352: acc_real = 1.0, acc_fake = 0.875
# Epoch 353: acc_real = 0.984375, acc_fake = 0.875
# Epoch 354: acc_real = 0.953125, acc_fake = 0.875
# Epoch 355: acc_real = 0.9375, acc_fake = 0.890625
# Epoch 356: acc_real = 1.0, acc_fake = 0.828125
# Epoch 357: acc_real = 0.984375, acc_fake = 0.828125
# Epoch 358: acc_real = 0.984375, acc_fake = 0.78125
# Epoch 359: acc_real = 0.984375, acc_fake = 0.90625
# Epoch 360: acc_real = 0.953125, acc_fake = 0.828125
# Epoch 361: acc_real = 0.984375, acc_fake = 0.84375
# Epoch 362: acc_real = 0.9375, acc_fake = 0.859375
# Epoch 363: acc_real = 0.953125, acc_fake = 0.859375
# Epoch 364: acc_real = 1.0, acc_fake = 0.765625
# Epoch 365: acc_real = 0.9375, acc_fake = 0.828125
# Epoch 366: acc_real = 0.96875, acc_fake = 0.78125
# Epoch 367: acc_real = 0.984375, acc_fake = 0.875
# Epoch 368: acc_real = 0.90625, acc_fake = 0.875
# Epoch 369: acc_real = 0.984375, acc_fake = 0.90625
# Epoch 370: acc_real = 0.96875, acc_fake = 0.796875
# Epoch 371: acc_real = 1.0, acc_fake = 0.921875
# Epoch 372: acc_real = 0.953125, acc_fake = 0.75
# Epoch 373: acc_real = 1.0, acc_fake = 0.953125
# Epoch 374: acc_real = 1.0, acc_fake = 0.890625
# Epoch 375: acc_real = 1.0, acc_fake = 0.765625
# Epoch 376: acc_real = 0.984375, acc_fake = 0.828125
# Epoch 377: acc_real = 1.0, acc_fake = 0.671875
# Epoch 378: acc_real = 0.96875, acc_fake = 0.90625
# Epoch 379: acc_real = 0.984375, acc_fake = 0.828125
# Epoch 380: acc_real = 1.0, acc_fake = 0.90625
# Epoch 381: acc_real = 0.96875, acc_fake = 0.765625
# Epoch 382: acc_real = 0.984375, acc_fake = 0.765625
# Epoch 383: acc_real = 0.96875, acc_fake = 0.828125
# Epoch 384: acc_real = 0.984375, acc_fake = 0.8125
# Epoch 385: acc_real = 0.984375, acc_fake = 0.890625
# Epoch 386: acc_real = 0.984375, acc_fake = 0.796875
# Epoch 387: acc_real = 1.0, acc_fake = 0.78125
# Epoch 388: acc_real = 0.96875, acc_fake = 0.859375
# Epoch 389: acc_real = 1.0, acc_fake = 0.859375
# Epoch 390: acc_real = 0.984375, acc_fake = 0.78125
# Epoch 391: acc_real = 0.984375, acc_fake = 0.890625
# Epoch 392: acc_real = 0.984375, acc_fake = 0.75
# Epoch 393: acc_real = 1.0, acc_fake = 0.828125
# Epoch 394: acc_real = 1.0, acc_fake = 0.84375
# Epoch 395: acc_real = 1.0, acc_fake = 0.8125
# Epoch 396: acc_real = 1.0, acc_fake = 0.875
# Epoch 397: acc_real = 1.0, acc_fake = 0.859375
# Epoch 398: acc_real = 0.96875, acc_fake = 0.890625
# Epoch 399: acc_real = 1.0, acc_fake = 0.8125
# Epoch 400: acc_real = 1.0, acc_fake = 0.84375
# Epoch 401: acc_real = 0.984375, acc_fake = 0.875
# Epoch 402: acc_real = 0.984375, acc_fake = 0.828125
# Epoch 403: acc_real = 0.984375, acc_fake = 0.828125
# Epoch 404: acc_real = 0.984375, acc_fake = 0.859375
# Epoch 405: acc_real = 1.0, acc_fake = 0.8125
# Epoch 406: acc_real = 0.984375, acc_fake = 0.734375
# Epoch 407: acc_real = 1.0, acc_fake = 0.90625
# Epoch 408: acc_real = 1.0, acc_fake = 0.859375
# Epoch 409: acc_real = 1.0, acc_fake = 0.90625
# Epoch 410: acc_real = 0.984375, acc_fake = 0.859375
# Epoch 411: acc_real = 0.984375, acc_fake = 0.84375
# Epoch 412: acc_real = 0.984375, acc_fake = 0.921875
# Epoch 413: acc_real = 1.0, acc_fake = 0.921875
# Epoch 414: acc_real = 1.0, acc_fake = 0.890625
# Epoch 415: acc_real = 0.984375, acc_fake = 0.8125
# Epoch 416: acc_real = 0.984375, acc_fake = 0.90625
# Epoch 417: acc_real = 1.0, acc_fake = 0.828125
# Epoch 418: acc_real = 0.984375, acc_fake = 0.828125
# Epoch 419: acc_real = 1.0, acc_fake = 0.8125
# Epoch 420: acc_real = 1.0, acc_fake = 0.828125
# Epoch 421: acc_real = 1.0, acc_fake = 0.84375
# Epoch 422: acc_real = 1.0, acc_fake = 0.875
# Epoch 423: acc_real = 1.0, acc_fake = 0.8125
# Epoch 424: acc_real = 1.0, acc_fake = 0.875
# Epoch 425: acc_real = 1.0, acc_fake = 0.875
# Epoch 426: acc_real = 1.0, acc_fake = 0.890625
# Epoch 427: acc_real = 1.0, acc_fake = 0.859375
# Epoch 428: acc_real = 1.0, acc_fake = 0.828125
# Epoch 429: acc_real = 1.0, acc_fake = 0.828125
# Epoch 430: acc_real = 1.0, acc_fake = 0.90625
# Epoch 431: acc_real = 1.0, acc_fake = 0.859375
# Epoch 432: acc_real = 1.0, acc_fake = 0.828125
# Epoch 433: acc_real = 1.0, acc_fake = 0.8125
# Epoch 434: acc_real = 1.0, acc_fake = 0.890625
# Epoch 435: acc_real = 1.0, acc_fake = 0.859375
# Epoch 436: acc_real = 1.0, acc_fake = 0.796875
# Epoch 437: acc_real = 1.0, acc_fake = 0.859375
# Epoch 438: acc_real = 1.0, acc_fake = 0.859375
# Epoch 439: acc_real = 1.0, acc_fake = 0.78125
# Epoch 440: acc_real = 1.0, acc_fake = 0.921875
# Epoch 441: acc_real = 1.0, acc_fake = 0.828125
# Epoch 442: acc_real = 1.0, acc_fake = 0.875
# Epoch 443: acc_real = 1.0, acc_fake = 0.9375
# Epoch 444: acc_real = 1.0, acc_fake = 0.84375
# Epoch 445: acc_real = 1.0, acc_fake = 0.875
# Epoch 446: acc_real = 1.0, acc_fake = 0.8125
# Epoch 447: acc_real = 1.0, acc_fake = 0.8125
# Epoch 448: acc_real = 1.0, acc_fake = 0.84375
# Epoch 449: acc_real = 1.0, acc_fake = 0.859375
# Epoch 450: acc_real = 1.0, acc_fake = 0.859375
# Epoch 451: acc_real = 1.0, acc_fake = 0.796875
# Epoch 452: acc_real = 1.0, acc_fake = 0.859375
# Epoch 453: acc_real = 1.0, acc_fake = 0.90625
# Epoch 454: acc_real = 1.0, acc_fake = 0.828125
# Epoch 455: acc_real = 1.0, acc_fake = 0.828125
# Epoch 456: acc_real = 1.0, acc_fake = 0.890625
# Epoch 457: acc_real = 1.0, acc_fake = 0.84375
# Epoch 458: acc_real = 1.0, acc_fake = 0.765625
# Epoch 459: acc_real = 1.0, acc_fake = 0.796875
# Epoch 460: acc_real = 1.0, acc_fake = 0.8125
# Epoch 461: acc_real = 1.0, acc_fake = 0.84375
# Epoch 462: acc_real = 1.0, acc_fake = 0.90625
# Epoch 463: acc_real = 1.0, acc_fake = 0.859375
# Epoch 464: acc_real = 1.0, acc_fake = 0.84375
# Epoch 465: acc_real = 1.0, acc_fake = 0.796875
# Epoch 466: acc_real = 1.0, acc_fake = 0.78125
# Epoch 467: acc_real = 1.0, acc_fake = 0.8125
# Epoch 468: acc_real = 1.0, acc_fake = 0.84375
# Epoch 469: acc_real = 1.0, acc_fake = 0.859375
# Epoch 470: acc_real = 1.0, acc_fake = 0.78125
# Epoch 471: acc_real = 1.0, acc_fake = 0.84375
# Epoch 472: acc_real = 1.0, acc_fake = 0.890625
# Epoch 473: acc_real = 1.0, acc_fake = 0.796875
# Epoch 474: acc_real = 1.0, acc_fake = 0.78125
# Epoch 475: acc_real = 1.0, acc_fake = 0.890625
# Epoch 476: acc_real = 1.0, acc_fake = 0.859375
# Epoch 477: acc_real = 1.0, acc_fake = 0.765625
# Epoch 478: acc_real = 1.0, acc_fake = 0.859375
# Epoch 479: acc_real = 1.0, acc_fake = 0.90625
# Epoch 480: acc_real = 1.0, acc_fake = 0.859375
# Epoch 481: acc_real = 1.0, acc_fake = 0.890625
# Epoch 482: acc_real = 1.0, acc_fake = 0.828125
# Epoch 483: acc_real = 1.0, acc_fake = 0.78125
# Epoch 484: acc_real = 1.0, acc_fake = 0.90625
# Epoch 485: acc_real = 1.0, acc_fake = 0.8125
# Epoch 486: acc_real = 1.0, acc_fake = 0.8125
# Epoch 487: acc_real = 1.0, acc_fake = 0.828125
# Epoch 488: acc_real = 1.0, acc_fake = 0.859375
# Epoch 489: acc_real = 1.0, acc_fake = 0.90625
# Epoch 490: acc_real = 1.0, acc_fake = 0.84375
# Epoch 491: acc_real = 1.0, acc_fake = 0.84375
# Epoch 492: acc_real = 1.0, acc_fake = 0.875
# Epoch 493: acc_real = 1.0, acc_fake = 0.84375
# Epoch 494: acc_real = 1.0, acc_fake = 0.875
# Epoch 495: acc_real = 1.0, acc_fake = 0.9375
# Epoch 496: acc_real = 1.0, acc_fake = 0.90625
# Epoch 497: acc_real = 1.0, acc_fake = 0.921875
# Epoch 498: acc_real = 1.0, acc_fake = 0.90625
# Epoch 499: acc_real = 1.0, acc_fake = 0.84375
# Epoch 500: acc_real = 1.0, acc_fake = 0.84375
# Epoch 501: acc_real = 1.0, acc_fake = 0.84375
# Epoch 502: acc_real = 1.0, acc_fake = 0.78125
# Epoch 503: acc_real = 1.0, acc_fake = 0.859375
# Epoch 504: acc_real = 1.0, acc_fake = 0.84375
# Epoch 505: acc_real = 1.0, acc_fake = 0.828125
# Epoch 506: acc_real = 1.0, acc_fake = 0.78125
# Epoch 507: acc_real = 1.0, acc_fake = 0.890625
# Epoch 508: acc_real = 1.0, acc_fake = 0.859375
# Epoch 509: acc_real = 1.0, acc_fake = 0.90625
# Epoch 510: acc_real = 1.0, acc_fake = 0.875
# Epoch 511: acc_real = 1.0, acc_fake = 0.84375
# Epoch 512: acc_real = 1.0, acc_fake = 0.828125
# Epoch 513: acc_real = 1.0, acc_fake = 0.828125
# Epoch 514: acc_real = 1.0, acc_fake = 0.84375
# Epoch 515: acc_real = 1.0, acc_fake = 0.921875
# Epoch 516: acc_real = 1.0, acc_fake = 0.84375
# Epoch 517: acc_real = 1.0, acc_fake = 0.796875
# Epoch 518: acc_real = 1.0, acc_fake = 0.765625
# Epoch 519: acc_real = 1.0, acc_fake = 0.84375
# Epoch 520: acc_real = 1.0, acc_fake = 0.875
# Epoch 521: acc_real = 1.0, acc_fake = 0.84375
# Epoch 522: acc_real = 1.0, acc_fake = 0.828125
# Epoch 523: acc_real = 1.0, acc_fake = 0.796875
# Epoch 524: acc_real = 1.0, acc_fake = 0.828125
# Epoch 525: acc_real = 1.0, acc_fake = 0.875
# Epoch 526: acc_real = 1.0, acc_fake = 0.75
# Epoch 527: acc_real = 1.0, acc_fake = 0.828125
# Epoch 528: acc_real = 1.0, acc_fake = 0.859375
# Epoch 529: acc_real = 1.0, acc_fake = 0.78125
# Epoch 530: acc_real = 1.0, acc_fake = 0.8125
# Epoch 531: acc_real = 1.0, acc_fake = 0.859375
# Epoch 532: acc_real = 1.0, acc_fake = 0.84375
# Epoch 533: acc_real = 1.0, acc_fake = 0.859375
# Epoch 534: acc_real = 1.0, acc_fake = 0.90625
# Epoch 535: acc_real = 1.0, acc_fake = 0.78125
# Epoch 536: acc_real = 1.0, acc_fake = 0.859375
# Epoch 537: acc_real = 1.0, acc_fake = 0.796875
# Epoch 538: acc_real = 1.0, acc_fake = 0.71875
# Epoch 539: acc_real = 1.0, acc_fake = 0.90625
# Epoch 540: acc_real = 1.0, acc_fake = 0.859375
# Epoch 541: acc_real = 1.0, acc_fake = 0.890625
# Epoch 542: acc_real = 1.0, acc_fake = 0.796875
# Epoch 543: acc_real = 1.0, acc_fake = 0.875
# Epoch 544: acc_real = 1.0, acc_fake = 0.84375
# Epoch 545: acc_real = 1.0, acc_fake = 0.796875
# Epoch 546: acc_real = 1.0, acc_fake = 0.78125
# Epoch 547: acc_real = 1.0, acc_fake = 0.796875
# Epoch 548: acc_real = 1.0, acc_fake = 0.78125
# Epoch 549: acc_real = 1.0, acc_fake = 0.828125
# Epoch 550: acc_real = 1.0, acc_fake = 0.890625
# Epoch 551: acc_real = 1.0, acc_fake = 0.859375
# Epoch 552: acc_real = 1.0, acc_fake = 0.890625
# Epoch 553: acc_real = 1.0, acc_fake = 0.796875
# Epoch 554: acc_real = 1.0, acc_fake = 0.828125
# Epoch 555: acc_real = 1.0, acc_fake = 0.875
# Epoch 556: acc_real = 1.0, acc_fake = 0.90625
# Epoch 557: acc_real = 1.0, acc_fake = 0.796875
# Epoch 558: acc_real = 1.0, acc_fake = 0.84375
# Epoch 559: acc_real = 1.0, acc_fake = 0.828125
# Epoch 560: acc_real = 1.0, acc_fake = 0.9375
# Epoch 561: acc_real = 1.0, acc_fake = 0.828125
# Epoch 562: acc_real = 1.0, acc_fake = 0.796875
# Epoch 563: acc_real = 1.0, acc_fake = 0.8125
# Epoch 564: acc_real = 1.0, acc_fake = 0.8125
# Epoch 565: acc_real = 1.0, acc_fake = 0.78125
# Epoch 566: acc_real = 1.0, acc_fake = 0.796875
# Epoch 567: acc_real = 1.0, acc_fake = 0.90625
# Epoch 568: acc_real = 1.0, acc_fake = 0.84375
# Epoch 569: acc_real = 1.0, acc_fake = 0.859375
# Epoch 570: acc_real = 1.0, acc_fake = 0.859375
# Epoch 571: acc_real = 1.0, acc_fake = 0.921875
# Epoch 572: acc_real = 1.0, acc_fake = 0.875
# Epoch 573: acc_real = 1.0, acc_fake = 0.84375
# Epoch 574: acc_real = 1.0, acc_fake = 0.75
# Epoch 575: acc_real = 1.0, acc_fake = 0.890625
# Epoch 576: acc_real = 1.0, acc_fake = 0.859375
# Epoch 577: acc_real = 1.0, acc_fake = 0.875
# Epoch 578: acc_real = 1.0, acc_fake = 0.796875
# Epoch 579: acc_real = 1.0, acc_fake = 0.84375
# Epoch 580: acc_real = 1.0, acc_fake = 0.859375
# Epoch 581: acc_real = 1.0, acc_fake = 0.828125
# Epoch 582: acc_real = 1.0, acc_fake = 0.84375
# Epoch 583: acc_real = 1.0, acc_fake = 0.875
# Epoch 584: acc_real = 1.0, acc_fake = 0.796875
# Epoch 585: acc_real = 1.0, acc_fake = 0.796875
# Epoch 586: acc_real = 1.0, acc_fake = 0.859375
# Epoch 587: acc_real = 1.0, acc_fake = 0.90625
# Epoch 588: acc_real = 1.0, acc_fake = 0.796875
# Epoch 589: acc_real = 1.0, acc_fake = 0.796875
# Epoch 590: acc_real = 1.0, acc_fake = 0.84375
# Epoch 591: acc_real = 1.0, acc_fake = 0.890625
# Epoch 592: acc_real = 1.0, acc_fake = 0.859375
# Epoch 593: acc_real = 1.0, acc_fake = 0.84375
# Epoch 594: acc_real = 1.0, acc_fake = 0.9375
# Epoch 595: acc_real = 1.0, acc_fake = 0.8125
# Epoch 596: acc_real = 1.0, acc_fake = 0.890625
# Epoch 597: acc_real = 1.0, acc_fake = 0.78125
# Epoch 598: acc_real = 1.0, acc_fake = 0.90625
# Epoch 599: acc_real = 1.0, acc_fake = 0.84375
# Epoch 600: acc_real = 1.0, acc_fake = 0.828125
# Epoch 601: acc_real = 1.0, acc_fake = 0.828125
# Epoch 602: acc_real = 1.0, acc_fake = 0.828125
# Epoch 603: acc_real = 1.0, acc_fake = 0.875
# Epoch 604: acc_real = 1.0, acc_fake = 0.90625
# Epoch 605: acc_real = 1.0, acc_fake = 0.890625
# Epoch 606: acc_real = 1.0, acc_fake = 0.84375
# Epoch 607: acc_real = 1.0, acc_fake = 0.90625
# Epoch 608: acc_real = 1.0, acc_fake = 0.796875
# Epoch 609: acc_real = 1.0, acc_fake = 0.8125
# Epoch 610: acc_real = 1.0, acc_fake = 0.828125
# Epoch 611: acc_real = 1.0, acc_fake = 0.796875
# Epoch 612: acc_real = 1.0, acc_fake = 0.921875
# Epoch 613: acc_real = 1.0, acc_fake = 0.96875
# Epoch 614: acc_real = 1.0, acc_fake = 0.828125
# Epoch 615: acc_real = 1.0, acc_fake = 0.859375
# Epoch 616: acc_real = 1.0, acc_fake = 0.765625
# Epoch 617: acc_real = 1.0, acc_fake = 0.875
# Epoch 618: acc_real = 1.0, acc_fake = 0.875
# Epoch 619: acc_real = 1.0, acc_fake = 0.875
# Epoch 620: acc_real = 1.0, acc_fake = 0.890625
# Epoch 621: acc_real = 1.0, acc_fake = 0.890625
# Epoch 622: acc_real = 1.0, acc_fake = 0.828125
# Epoch 623: acc_real = 1.0, acc_fake = 0.921875
# Epoch 624: acc_real = 1.0, acc_fake = 0.828125
# Epoch 625: acc_real = 1.0, acc_fake = 0.8125
# Epoch 626: acc_real = 1.0, acc_fake = 0.875
# Epoch 627: acc_real = 1.0, acc_fake = 0.859375
# Epoch 628: acc_real = 1.0, acc_fake = 0.96875
# Epoch 629: acc_real = 1.0, acc_fake = 0.796875
# Epoch 630: acc_real = 1.0, acc_fake = 0.90625
# Epoch 631: acc_real = 1.0, acc_fake = 0.8125
# Epoch 632: acc_real = 1.0, acc_fake = 0.9375
# Epoch 633: acc_real = 1.0, acc_fake = 0.890625
# Epoch 634: acc_real = 1.0, acc_fake = 0.890625
# Epoch 635: acc_real = 1.0, acc_fake = 0.890625
# Epoch 636: acc_real = 1.0, acc_fake = 0.890625
# Epoch 637: acc_real = 1.0, acc_fake = 0.796875
# Epoch 638: acc_real = 1.0, acc_fake = 0.859375
# Epoch 639: acc_real = 1.0, acc_fake = 0.890625
# Epoch 640: acc_real = 1.0, acc_fake = 0.921875
# Epoch 641: acc_real = 1.0, acc_fake = 0.796875
# Epoch 642: acc_real = 1.0, acc_fake = 0.828125
# Epoch 643: acc_real = 1.0, acc_fake = 0.828125
# Epoch 644: acc_real = 1.0, acc_fake = 0.8125
# Epoch 645: acc_real = 1.0, acc_fake = 0.859375
# Epoch 646: acc_real = 1.0, acc_fake = 0.921875
# Epoch 647: acc_real = 1.0, acc_fake = 0.75
# Epoch 648: acc_real = 1.0, acc_fake = 0.78125
# Epoch 649: acc_real = 1.0, acc_fake = 0.828125
# Epoch 650: acc_real = 1.0, acc_fake = 0.859375
# Epoch 651: acc_real = 1.0, acc_fake = 0.796875
# Epoch 652: acc_real = 1.0, acc_fake = 0.890625
# Epoch 653: acc_real = 1.0, acc_fake = 0.90625
# Epoch 654: acc_real = 1.0, acc_fake = 0.875
# Epoch 655: acc_real = 1.0, acc_fake = 0.8125
# Epoch 656: acc_real = 1.0, acc_fake = 0.796875
# Epoch 657: acc_real = 1.0, acc_fake = 0.90625
# Epoch 658: acc_real = 1.0, acc_fake = 0.828125
# Epoch 659: acc_real = 1.0, acc_fake = 0.796875
# Epoch 660: acc_real = 1.0, acc_fake = 0.8125
# Epoch 661: acc_real = 1.0, acc_fake = 0.875
# Epoch 662: acc_real = 1.0, acc_fake = 0.875
# Epoch 663: acc_real = 1.0, acc_fake = 0.796875
# Epoch 664: acc_real = 1.0, acc_fake = 0.875
# Epoch 665: acc_real = 1.0, acc_fake = 0.9375
# Epoch 666: acc_real = 1.0, acc_fake = 0.765625
# Epoch 667: acc_real = 1.0, acc_fake = 0.875
# Epoch 668: acc_real = 1.0, acc_fake = 0.890625
# Epoch 669: acc_real = 1.0, acc_fake = 0.84375
# Epoch 670: acc_real = 1.0, acc_fake = 0.71875
# Epoch 671: acc_real = 1.0, acc_fake = 0.859375
# Epoch 672: acc_real = 1.0, acc_fake = 0.859375
# Epoch 673: acc_real = 1.0, acc_fake = 0.859375
# Epoch 674: acc_real = 1.0, acc_fake = 0.84375
# Epoch 675: acc_real = 1.0, acc_fake = 0.859375
# Epoch 676: acc_real = 1.0, acc_fake = 0.84375
# Epoch 677: acc_real = 1.0, acc_fake = 0.875
# Epoch 678: acc_real = 1.0, acc_fake = 0.96875
# Epoch 679: acc_real = 1.0, acc_fake = 0.890625
# Epoch 680: acc_real = 1.0, acc_fake = 0.78125
# Epoch 681: acc_real = 1.0, acc_fake = 0.6875
# Epoch 682: acc_real = 1.0, acc_fake = 0.859375
# Epoch 683: acc_real = 1.0, acc_fake = 0.84375
# Epoch 684: acc_real = 1.0, acc_fake = 0.8125
# Epoch 685: acc_real = 1.0, acc_fake = 0.890625
# Epoch 686: acc_real = 1.0, acc_fake = 0.78125
# Epoch 687: acc_real = 1.0, acc_fake = 0.921875
# Epoch 688: acc_real = 1.0, acc_fake = 0.90625
# Epoch 689: acc_real = 1.0, acc_fake = 0.921875
# Epoch 690: acc_real = 1.0, acc_fake = 0.90625
# Epoch 691: acc_real = 1.0, acc_fake = 0.828125
# Epoch 692: acc_real = 1.0, acc_fake = 0.828125
# Epoch 693: acc_real = 1.0, acc_fake = 0.78125
# Epoch 694: acc_real = 1.0, acc_fake = 0.859375
# Epoch 695: acc_real = 1.0, acc_fake = 0.859375
# Epoch 696: acc_real = 1.0, acc_fake = 0.828125
# Epoch 697: acc_real = 1.0, acc_fake = 0.796875
# Epoch 698: acc_real = 1.0, acc_fake = 0.84375
# Epoch 699: acc_real = 1.0, acc_fake = 0.859375
# Epoch 700: acc_real = 1.0, acc_fake = 0.859375
# Epoch 701: acc_real = 1.0, acc_fake = 0.875
# Epoch 702: acc_real = 1.0, acc_fake = 0.84375
# Epoch 703: acc_real = 1.0, acc_fake = 0.875
# Epoch 704: acc_real = 1.0, acc_fake = 0.859375
# Epoch 705: acc_real = 1.0, acc_fake = 0.921875
# Epoch 706: acc_real = 1.0, acc_fake = 0.875
# Epoch 707: acc_real = 1.0, acc_fake = 0.859375
# Epoch 708: acc_real = 1.0, acc_fake = 0.890625
# Epoch 709: acc_real = 1.0, acc_fake = 0.859375
# Epoch 710: acc_real = 1.0, acc_fake = 0.90625
# Epoch 711: acc_real = 1.0, acc_fake = 0.796875
# Epoch 712: acc_real = 1.0, acc_fake = 0.78125
# Epoch 713: acc_real = 1.0, acc_fake = 0.875
# Epoch 714: acc_real = 1.0, acc_fake = 0.765625
# Epoch 715: acc_real = 1.0, acc_fake = 0.828125
# Epoch 716: acc_real = 1.0, acc_fake = 0.90625
# Epoch 717: acc_real = 1.0, acc_fake = 0.796875
# Epoch 718: acc_real = 1.0, acc_fake = 0.859375
# Epoch 719: acc_real = 1.0, acc_fake = 0.890625
# Epoch 720: acc_real = 1.0, acc_fake = 0.8125
# Epoch 721: acc_real = 1.0, acc_fake = 0.84375
# Epoch 722: acc_real = 1.0, acc_fake = 0.84375
# Epoch 723: acc_real = 1.0, acc_fake = 0.953125
# Epoch 724: acc_real = 1.0, acc_fake = 0.84375
# Epoch 725: acc_real = 1.0, acc_fake = 0.875
# Epoch 726: acc_real = 1.0, acc_fake = 0.890625
# Epoch 727: acc_real = 1.0, acc_fake = 0.953125
# Epoch 728: acc_real = 1.0, acc_fake = 0.84375
# Epoch 729: acc_real = 1.0, acc_fake = 0.890625
# Epoch 730: acc_real = 1.0, acc_fake = 0.859375
# Epoch 731: acc_real = 1.0, acc_fake = 0.8125
# Epoch 732: acc_real = 1.0, acc_fake = 0.859375
# Epoch 733: acc_real = 1.0, acc_fake = 0.875
# Epoch 734: acc_real = 1.0, acc_fake = 0.828125
# Epoch 735: acc_real = 1.0, acc_fake = 0.859375
# Epoch 736: acc_real = 1.0, acc_fake = 0.84375
# Epoch 737: acc_real = 1.0, acc_fake = 0.859375
# Epoch 738: acc_real = 1.0, acc_fake = 0.828125
# Epoch 739: acc_real = 1.0, acc_fake = 0.828125
# Epoch 740: acc_real = 1.0, acc_fake = 0.828125
# Epoch 741: acc_real = 1.0, acc_fake = 0.890625
# Epoch 742: acc_real = 1.0, acc_fake = 0.859375
# Epoch 743: acc_real = 1.0, acc_fake = 0.90625
# Epoch 744: acc_real = 1.0, acc_fake = 0.859375
# Epoch 745: acc_real = 1.0, acc_fake = 0.84375
# Epoch 746: acc_real = 1.0, acc_fake = 0.875
# Epoch 747: acc_real = 1.0, acc_fake = 0.859375
# Epoch 748: acc_real = 1.0, acc_fake = 0.84375
# Epoch 749: acc_real = 1.0, acc_fake = 0.828125
# Epoch 750: acc_real = 1.0, acc_fake = 0.796875
# Epoch 751: acc_real = 1.0, acc_fake = 0.84375
# Epoch 752: acc_real = 1.0, acc_fake = 0.875
# Epoch 753: acc_real = 1.0, acc_fake = 0.8125
# Epoch 754: acc_real = 1.0, acc_fake = 0.875
# Epoch 755: acc_real = 1.0, acc_fake = 0.828125
# Epoch 756: acc_real = 1.0, acc_fake = 0.8125
# Epoch 757: acc_real = 1.0, acc_fake = 0.859375
# Epoch 758: acc_real = 1.0, acc_fake = 0.84375
# Epoch 759: acc_real = 1.0, acc_fake = 0.875
# Epoch 760: acc_real = 1.0, acc_fake = 0.875
# Epoch 761: acc_real = 1.0, acc_fake = 0.875
# Epoch 762: acc_real = 1.0, acc_fake = 0.78125
# Epoch 763: acc_real = 1.0, acc_fake = 0.828125
# Epoch 764: acc_real = 1.0, acc_fake = 0.875
# Epoch 765: acc_real = 1.0, acc_fake = 0.890625
# Epoch 766: acc_real = 1.0, acc_fake = 0.90625
# Epoch 767: acc_real = 1.0, acc_fake = 0.8125
# Epoch 768: acc_real = 1.0, acc_fake = 0.921875
# Epoch 769: acc_real = 1.0, acc_fake = 0.859375
# Epoch 770: acc_real = 1.0, acc_fake = 0.859375
# Epoch 771: acc_real = 1.0, acc_fake = 0.859375
# Epoch 772: acc_real = 1.0, acc_fake = 0.890625
# Epoch 773: acc_real = 1.0, acc_fake = 0.84375
# Epoch 774: acc_real = 1.0, acc_fake = 0.953125
# Epoch 775: acc_real = 1.0, acc_fake = 0.875
# Epoch 776: acc_real = 1.0, acc_fake = 0.9375
# Epoch 777: acc_real = 1.0, acc_fake = 0.890625
# Epoch 778: acc_real = 1.0, acc_fake = 0.859375
# Epoch 779: acc_real = 1.0, acc_fake = 0.84375
# Epoch 780: acc_real = 1.0, acc_fake = 0.84375
# Epoch 781: acc_real = 1.0, acc_fake = 0.859375
# Epoch 782: acc_real = 1.0, acc_fake = 0.859375
# Epoch 783: acc_real = 1.0, acc_fake = 0.875
# Epoch 784: acc_real = 1.0, acc_fake = 0.828125
# Epoch 785: acc_real = 1.0, acc_fake = 0.890625
# Epoch 786: acc_real = 1.0, acc_fake = 0.859375
# Epoch 787: acc_real = 1.0, acc_fake = 0.90625
# Epoch 788: acc_real = 1.0, acc_fake = 0.828125
# Epoch 789: acc_real = 1.0, acc_fake = 0.90625
# Epoch 790: acc_real = 1.0, acc_fake = 0.859375
# Epoch 791: acc_real = 1.0, acc_fake = 0.890625
# Epoch 792: acc_real = 1.0, acc_fake = 0.84375
# Epoch 793: acc_real = 1.0, acc_fake = 0.84375
# Epoch 794: acc_real = 1.0, acc_fake = 0.921875
# Epoch 795: acc_real = 1.0, acc_fake = 0.890625
# Epoch 796: acc_real = 1.0, acc_fake = 0.828125
# Epoch 797: acc_real = 1.0, acc_fake = 0.84375
# Epoch 798: acc_real = 1.0, acc_fake = 0.859375
# Epoch 799: acc_real = 1.0, acc_fake = 0.84375
# Epoch 800: acc_real = 1.0, acc_fake = 0.765625
# Epoch 801: acc_real = 1.0, acc_fake = 0.890625
# Epoch 802: acc_real = 1.0, acc_fake = 0.875
# Epoch 803: acc_real = 1.0, acc_fake = 0.890625
# Epoch 804: acc_real = 1.0, acc_fake = 0.796875
# Epoch 805: acc_real = 1.0, acc_fake = 0.859375
# Epoch 806: acc_real = 1.0, acc_fake = 0.90625
# Epoch 807: acc_real = 1.0, acc_fake = 0.84375
# Epoch 808: acc_real = 1.0, acc_fake = 0.90625
# Epoch 809: acc_real = 1.0, acc_fake = 0.859375
# Epoch 810: acc_real = 1.0, acc_fake = 0.90625
# Epoch 811: acc_real = 1.0, acc_fake = 0.890625
# Epoch 812: acc_real = 1.0, acc_fake = 0.90625
# Epoch 813: acc_real = 1.0, acc_fake = 0.84375
# Epoch 814: acc_real = 1.0, acc_fake = 0.859375
# Epoch 815: acc_real = 1.0, acc_fake = 0.921875
# Epoch 816: acc_real = 1.0, acc_fake = 0.828125
# Epoch 817: acc_real = 1.0, acc_fake = 0.796875
# Epoch 818: acc_real = 1.0, acc_fake = 0.875
# Epoch 819: acc_real = 1.0, acc_fake = 0.84375
# Epoch 820: acc_real = 1.0, acc_fake = 0.859375
# Epoch 821: acc_real = 1.0, acc_fake = 0.8125
# Epoch 822: acc_real = 1.0, acc_fake = 0.890625
# Epoch 823: acc_real = 1.0, acc_fake = 0.921875
# Epoch 824: acc_real = 1.0, acc_fake = 0.8125
# Epoch 825: acc_real = 1.0, acc_fake = 0.828125
# Epoch 826: acc_real = 1.0, acc_fake = 0.859375
# Epoch 827: acc_real = 0.984375, acc_fake = 0.875
# Epoch 828: acc_real = 1.0, acc_fake = 0.84375
# Epoch 829: acc_real = 1.0, acc_fake = 0.90625
# Epoch 830: acc_real = 1.0, acc_fake = 0.84375
# Epoch 831: acc_real = 1.0, acc_fake = 0.875
# Epoch 832: acc_real = 0.984375, acc_fake = 0.875
# Epoch 833: acc_real = 1.0, acc_fake = 0.890625
# Epoch 834: acc_real = 1.0, acc_fake = 0.890625
# Epoch 835: acc_real = 0.984375, acc_fake = 0.890625
# Epoch 836: acc_real = 1.0, acc_fake = 0.921875
# Epoch 837: acc_real = 1.0, acc_fake = 0.8125
# Epoch 838: acc_real = 1.0, acc_fake = 0.78125
# Epoch 839: acc_real = 1.0, acc_fake = 0.90625
# Epoch 840: acc_real = 1.0, acc_fake = 0.828125
# Epoch 841: acc_real = 1.0, acc_fake = 0.921875
# Epoch 842: acc_real = 1.0, acc_fake = 0.875
# Epoch 843: acc_real = 1.0, acc_fake = 0.859375
# Epoch 844: acc_real = 1.0, acc_fake = 0.84375
# Epoch 845: acc_real = 1.0, acc_fake = 0.890625
# Epoch 846: acc_real = 1.0, acc_fake = 0.84375
# Epoch 847: acc_real = 1.0, acc_fake = 0.875
# Epoch 848: acc_real = 0.984375, acc_fake = 0.84375
# Epoch 849: acc_real = 1.0, acc_fake = 0.890625
# Epoch 850: acc_real = 1.0, acc_fake = 0.84375
# Epoch 851: acc_real = 1.0, acc_fake = 0.859375
# Epoch 852: acc_real = 1.0, acc_fake = 0.890625
# Epoch 853: acc_real = 1.0, acc_fake = 0.828125
# Epoch 854: acc_real = 1.0, acc_fake = 0.90625
# Epoch 855: acc_real = 1.0, acc_fake = 0.890625
# Epoch 856: acc_real = 1.0, acc_fake = 0.9375
# Epoch 857: acc_real = 1.0, acc_fake = 0.84375
# Epoch 858: acc_real = 1.0, acc_fake = 0.875
# Epoch 859: acc_real = 1.0, acc_fake = 0.8125
# Epoch 860: acc_real = 1.0, acc_fake = 0.84375
# Epoch 861: acc_real = 1.0, acc_fake = 0.890625
# Epoch 862: acc_real = 1.0, acc_fake = 0.875
# Epoch 863: acc_real = 1.0, acc_fake = 0.84375
# Epoch 864: acc_real = 1.0, acc_fake = 0.875
# Epoch 865: acc_real = 1.0, acc_fake = 0.890625
# Epoch 866: acc_real = 1.0, acc_fake = 0.921875
# Epoch 867: acc_real = 1.0, acc_fake = 0.828125
# Epoch 868: acc_real = 1.0, acc_fake = 0.84375
# Epoch 869: acc_real = 1.0, acc_fake = 0.859375
# Epoch 870: acc_real = 1.0, acc_fake = 0.84375
# Epoch 871: acc_real = 1.0, acc_fake = 0.890625
# Epoch 872: acc_real = 1.0, acc_fake = 0.90625
# Epoch 873: acc_real = 1.0, acc_fake = 0.9375
# Epoch 874: acc_real = 1.0, acc_fake = 0.796875
# Epoch 875: acc_real = 1.0, acc_fake = 0.90625
# Epoch 876: acc_real = 1.0, acc_fake = 0.84375
# Epoch 877: acc_real = 1.0, acc_fake = 0.875
# Epoch 878: acc_real = 1.0, acc_fake = 0.875
# Epoch 879: acc_real = 1.0, acc_fake = 0.765625
# Epoch 880: acc_real = 1.0, acc_fake = 0.90625
# Epoch 881: acc_real = 1.0, acc_fake = 0.96875
# Epoch 882: acc_real = 1.0, acc_fake = 0.84375
# Epoch 883: acc_real = 1.0, acc_fake = 0.890625
# Epoch 884: acc_real = 1.0, acc_fake = 0.84375
# Epoch 885: acc_real = 1.0, acc_fake = 0.90625
# Epoch 886: acc_real = 1.0, acc_fake = 0.84375
# Epoch 887: acc_real = 1.0, acc_fake = 0.921875
# Epoch 888: acc_real = 1.0, acc_fake = 0.859375
# Epoch 889: acc_real = 1.0, acc_fake = 0.921875
# Epoch 890: acc_real = 1.0, acc_fake = 0.859375
# Epoch 891: acc_real = 1.0, acc_fake = 0.890625
# Epoch 892: acc_real = 1.0, acc_fake = 0.828125
# Epoch 893: acc_real = 1.0, acc_fake = 0.859375
# Epoch 894: acc_real = 1.0, acc_fake = 0.921875
# Epoch 895: acc_real = 1.0, acc_fake = 0.8125
# Epoch 896: acc_real = 1.0, acc_fake = 0.921875
# Epoch 897: acc_real = 1.0, acc_fake = 0.953125
# Epoch 898: acc_real = 1.0, acc_fake = 0.859375
# Epoch 899: acc_real = 1.0, acc_fake = 0.875
# Epoch 900: acc_real = 1.0, acc_fake = 0.796875
# Epoch 901: acc_real = 1.0, acc_fake = 0.8125
# Epoch 902: acc_real = 1.0, acc_fake = 0.890625
# Epoch 903: acc_real = 1.0, acc_fake = 0.9375
# Epoch 904: acc_real = 1.0, acc_fake = 0.9375
# Epoch 905: acc_real = 0.984375, acc_fake = 0.875
# Epoch 906: acc_real = 1.0, acc_fake = 0.828125
# Epoch 907: acc_real = 1.0, acc_fake = 0.859375
# Epoch 908: acc_real = 0.984375, acc_fake = 0.890625
# Epoch 909: acc_real = 1.0, acc_fake = 0.875
# Epoch 910: acc_real = 0.984375, acc_fake = 0.890625
# Epoch 911: acc_real = 1.0, acc_fake = 0.90625
# Epoch 912: acc_real = 0.984375, acc_fake = 0.921875
# Epoch 913: acc_real = 1.0, acc_fake = 0.859375
# Epoch 914: acc_real = 1.0, acc_fake = 0.9375
# Epoch 915: acc_real = 1.0, acc_fake = 0.875
# Epoch 916: acc_real = 1.0, acc_fake = 0.84375
# Epoch 917: acc_real = 1.0, acc_fake = 0.859375
# Epoch 918: acc_real = 1.0, acc_fake = 0.828125
# Epoch 919: acc_real = 1.0, acc_fake = 0.921875
# Epoch 920: acc_real = 1.0, acc_fake = 0.828125
# Epoch 921: acc_real = 1.0, acc_fake = 0.828125
# Epoch 922: acc_real = 1.0, acc_fake = 0.875
# Epoch 923: acc_real = 1.0, acc_fake = 0.84375
# Epoch 924: acc_real = 1.0, acc_fake = 0.859375
# Epoch 925: acc_real = 1.0, acc_fake = 0.9375
# Epoch 926: acc_real = 1.0, acc_fake = 0.859375
# Epoch 927: acc_real = 1.0, acc_fake = 0.890625
# Epoch 928: acc_real = 1.0, acc_fake = 0.921875
# Epoch 929: acc_real = 1.0, acc_fake = 0.859375
# Epoch 930: acc_real = 1.0, acc_fake = 0.921875
# Epoch 931: acc_real = 1.0, acc_fake = 0.84375
# Epoch 932: acc_real = 1.0, acc_fake = 0.828125
# Epoch 933: acc_real = 1.0, acc_fake = 0.875
# Epoch 934: acc_real = 1.0, acc_fake = 0.875
# Epoch 935: acc_real = 1.0, acc_fake = 0.875
# Epoch 936: acc_real = 1.0, acc_fake = 0.828125
# Epoch 937: acc_real = 1.0, acc_fake = 0.828125
# Epoch 938: acc_real = 0.984375, acc_fake = 0.9375
# Epoch 939: acc_real = 0.984375, acc_fake = 0.859375
# Epoch 940: acc_real = 0.984375, acc_fake = 0.890625
# Epoch 941: acc_real = 1.0, acc_fake = 0.890625
# Epoch 942: acc_real = 1.0, acc_fake = 0.8125
# Epoch 943: acc_real = 1.0, acc_fake = 0.875
# Epoch 944: acc_real = 1.0, acc_fake = 0.90625
# Epoch 945: acc_real = 0.96875, acc_fake = 0.921875
# Epoch 946: acc_real = 0.984375, acc_fake = 0.859375
# Epoch 947: acc_real = 1.0, acc_fake = 0.875
# Epoch 948: acc_real = 1.0, acc_fake = 0.9375
# Epoch 949: acc_real = 1.0, acc_fake = 0.875
# Epoch 950: acc_real = 1.0, acc_fake = 0.890625
# Epoch 951: acc_real = 1.0, acc_fake = 0.765625
# Epoch 952: acc_real = 1.0, acc_fake = 0.90625
# Epoch 953: acc_real = 1.0, acc_fake = 0.84375
# Epoch 954: acc_real = 1.0, acc_fake = 0.859375
# Epoch 955: acc_real = 1.0, acc_fake = 0.921875
# Epoch 956: acc_real = 1.0, acc_fake = 0.875
# Epoch 957: acc_real = 1.0, acc_fake = 0.828125
# Epoch 958: acc_real = 1.0, acc_fake = 0.890625
# Epoch 959: acc_real = 1.0, acc_fake = 0.796875
# Epoch 960: acc_real = 1.0, acc_fake = 0.890625
# Epoch 961: acc_real = 1.0, acc_fake = 0.9375
# Epoch 962: acc_real = 1.0, acc_fake = 0.921875
# Epoch 963: acc_real = 1.0, acc_fake = 0.859375
# Epoch 964: acc_real = 1.0, acc_fake = 0.890625
# Epoch 965: acc_real = 1.0, acc_fake = 0.84375
# Epoch 966: acc_real = 1.0, acc_fake = 0.875
# Epoch 967: acc_real = 1.0, acc_fake = 0.90625
# Epoch 968: acc_real = 1.0, acc_fake = 0.859375
# Epoch 969: acc_real = 1.0, acc_fake = 0.828125
# Epoch 970: acc_real = 1.0, acc_fake = 0.875
# Epoch 971: acc_real = 1.0, acc_fake = 0.859375
# Epoch 972: acc_real = 1.0, acc_fake = 0.890625
# Epoch 973: acc_real = 1.0, acc_fake = 0.828125
# Epoch 974: acc_real = 1.0, acc_fake = 0.9375
# Epoch 975: acc_real = 1.0, acc_fake = 0.921875
# Epoch 976: acc_real = 1.0, acc_fake = 0.921875
# Epoch 977: acc_real = 1.0, acc_fake = 0.90625
# Epoch 978: acc_real = 1.0, acc_fake = 0.90625
# Epoch 979: acc_real = 1.0, acc_fake = 0.84375
# Epoch 980: acc_real = 1.0, acc_fake = 0.859375
# Epoch 981: acc_real = 1.0, acc_fake = 0.8125
# Epoch 982: acc_real = 1.0, acc_fake = 0.84375
# Epoch 983: acc_real = 1.0, acc_fake = 0.921875
# Epoch 984: acc_real = 1.0, acc_fake = 0.875
# Epoch 985: acc_real = 1.0, acc_fake = 0.875
# Epoch 986: acc_real = 1.0, acc_fake = 0.890625
# Epoch 987: acc_real = 1.0, acc_fake = 0.90625
# Epoch 988: acc_real = 1.0, acc_fake = 0.75
# Epoch 989: acc_real = 1.0, acc_fake = 0.921875
# Epoch 990: acc_real = 1.0, acc_fake = 0.90625
# Epoch 991: acc_real = 1.0, acc_fake = 0.84375
# Epoch 992: acc_real = 1.0, acc_fake = 0.8125
# Epoch 993: acc_real = 1.0, acc_fake = 0.890625
# Epoch 994: acc_real = 1.0, acc_fake = 0.90625
# Epoch 995: acc_real = 1.0, acc_fake = 0.890625
# Epoch 996: acc_real = 1.0, acc_fake = 0.96875
# Epoch 997: acc_real = 1.0, acc_fake = 0.875
# Epoch 998: acc_real = 1.0, acc_fake = 0.875
# Epoch 999: acc_real = 1.0, acc_fake = 0.859375

# %%
plt.title('Learning curves for real samples')
plt.xlabel('Epoch')
plt.plot(epoch_hist_real)
plt.legend(model.metrics_names)
plt.show()

plt.title('Learning curves for fake samples')
plt.xlabel('Epoch')
plt.plot(epoch_hist_fake)
plt.legend(model.metrics_names)
plt.show();

# %% [markdown]
# ## 3. Define a Generator Model
# - Takes a point from latent (hidden) space to generate a new sample (point with X1 and X2 coordinates)
# - Latent space is assigned meaning through the training of the generator model - afterwards points in latent space correspond to points in the output space
# - Define latent space with 5 dimensions, each with a Gaussion distribution
# - Generation of new inputs by drawing random numbers from a standard Gaussian distribution (mean = 0, std.dev. = 1)
# - In: point in latent space, vector with 5 elements from Gaussian distribution
# - Out: point in output space, vector with 2 elements, X1 and X2 (or x and f(x))

# %%
def define_generator(latent_dim, n_outputs=2):
    model = Sequential()
    model.add(Dense(15, activation='relu', kernel_initializer='he_uniform', input_dim=latent_dim))
    model.add(Dense(n_outputs, activation='linear'))
    return model

model = define_generator(5)
model.summary()
plot_model(model, to_file='GAN_1D_Keras_generator_plot.png', show_shapes=True, show_layer_names=True);
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 15)                90
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 32
# =================================================================
# Total params: 122
# Trainable params: 122
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Generator Model Plot
# ![Generator Model](GAN_1D_Keras_generator_plot.png 'Generator Model')

# %%
def generate_latent_points(latent_dim, n):
    '''Generate points in latent space: return n rows of latent_dim points as input for the network.'''
    x_input = np.random.randn(latent_dim * n)
    x_input = x_input.reshape(n, latent_dim)
    return x_input

def generate_fake_points(generator, latent_dim, n):
    '''Generate fake points based on input from latent space.'''
    x_input = generate_latent_points(latent_dim, n)
    X = generator.predict(x_input)
    # Disable plotting for training, otherwise outputs 1 plot per epoch!
    #plt.scatter(X[:, 0], X[:, 1])
    #plt.show()
    y = np.zeros((n, 1))
    return X, y

# %%
latent_dim = 5
model = define_generator(latent_dim)
generate_fake_points(model, latent_dim, 100);

# %% [markdown]
# ## 4. Training the Generator Model
# - Update weights in the generator model based on the performance of the discriminator model
# - Good discriminator performance changes weights of generator more, bad discriminator performance leads to less change --> **adversarial relationship**
# - Stack generator and discriminator, so that G receives as input latent space points, generates samples that are fed to D model directly and get classified. Output of this model updates weights of generator.
# - In overall model, discriminator model layers must be *non-trainable* to avoid overtraining on fake examples
# - Discriminator model must think that generator output samples are real, not fake --> classified as 1
# - Leads to large initial error (since actual class is 0, fake) --> large change of weights in generator model

# %%
def define_gan(generator, discriminator):
    '''Defines an overall stacked model from the generator and discriminator, with the later tagged as untrainable.'''
    discriminator.trainable = False
    model = Sequential()
    model.add(generator)
    model.add(discriminator)
    model.compile(loss='binary_crossentropy', optimizer='adam')
    return model

# %%
latent_dim = 5
discriminator = define_discriminator()
generator = define_generator(latent_dim)
gan_model = define_gan(generator, discriminator)
gan_model.summary()
plot_model(gan_model, to_file='GAN_1D_Keras_gan_plot.png', show_shapes=True, show_layer_names=True, expand_nested=True);
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_19 (Sequential)   (None, 2)                 122
# _________________________________________________________________
# sequential_18 (Sequential)   (None, 1)                 101
# =================================================================
# Total params: 223
# Trainable params: 122
# Non-trainable params: 101
# _________________________________________________________________

# %% [markdown]
# #### GAN Model Plot
# ![GAN Model](GAN_1D_Keras_gan_plot.png 'GAN Model')

# %%
def train_gan(g_model, d_model, gan_model, latent_dim, n_epochs=10000, n_batch=128):
    '''Train generator and discriminator models.'''
    half_batch = int(n_batch/2)
    for i in range(n_epochs):
        x_real, y_real = generate_real_samples(half_batch)
        x_fake, y_fake = generate_fake_points(g_model, latent_dim, half_batch)
        d_model.train_on_batch(x_real, y_real)
        d_model.train_on_batch(x_fake, y_fake)
        x_gan = generate_latent_points(latent_dim, n_batch)
        y_gan = np.ones((n_batch, 1))
        gan_model.train_on_batch(x_gan, y_gan)    
    return

# %% [markdown]
# ## 5. Evaluating the Performance of the GAN
# - Generally, there are no objective ways to evaluate the performance of a GAN model.
# - For a known function, however, objective quality can be calculated i.e. via MSE.
# - Real use cases use subjective judgement by comparing generated samples to real samples.

# %%
def summarize_performance(epoch, generator, discriminator, latent_dim, n=100):
    X_real, y_real = generate_real_samples(n)
    _, acc_real = discriminator.evaluate(X_real, y_real, verbose=0)
    X_fake, y_fake = generate_fake_points(generator, latent_dim, n)
    _, acc_fake = discriminator.evaluate(X_fake, y_fake, verbose=0)
    print('Epoch {}: acc_real = {:.2}, acc_fake = {:.2}'.format(epoch, acc_real, acc_fake))
    plt.title('Comparison of real and generated fake data points.')
    leg_real = plt.scatter(X_real[:, 0], X_real[:, 1], marker='s')
    leg_fake = plt.scatter(X_fake[:, 0], X_fake[:, 1])
    plt.legend((leg_real, leg_fake), ('real', 'fake'))
    plt.show()
    return

summarize_performance(0, generator, discriminator, latent_dim)
# Out:
# Epoch 0: acc_real = 0.96, acc_fake = 0.84

# %%
def train(g_model, d_model, gan_model, latent_dim, n_epochs=10000, n_batch=128, n_eval=2000):
    '''Train generator and discriminator models.'''
    half_batch = int(n_batch/2)
    for i in range(n_epochs):
        x_real, y_real = generate_real_samples(half_batch)
        x_fake, y_fake = generate_fake_points(g_model, latent_dim, half_batch)
        d_model.train_on_batch(x_real, y_real)
        d_model.train_on_batch(x_fake, y_fake)
        x_gan = generate_latent_points(latent_dim, n_batch)
        y_gan = np.ones((n_batch, 1))
        gan_model.train_on_batch(x_gan, y_gan)
        if(i+1) % n_eval == 0:
            summarize_performance(i+1, g_model, d_model, latent_dim)
    summarize_performance(i+1, g_model, d_model, latent_dim)
    return

# %% [markdown]
# ## 6. Running the model
# - If model learns correctly, accuracy of classification of the fake generated data points should decrease and finish at around 50% (since 50% of the points are real and 50% are fake)

# %%
latent_dim = 5
n_epochs = 12000
n_batch = 256
n_eval = 2000

discriminator = define_discriminator()
generator = define_generator(latent_dim)
gan_model = define_gan(generator, discriminator)
train(generator, discriminator, gan_model, latent_dim, n_epochs, n_batch, n_eval)
#train(generator, discriminator, gan_model, latent_dim)
# Out:
# Epoch 2000: acc_real = 0.57, acc_fake = 0.59
# Epoch 4000: acc_real = 0.79, acc_fake = 0.33
# Epoch 6000: acc_real = 0.13, acc_fake = 0.99
# Epoch 8000: acc_real = 0.41, acc_fake = 0.68
# Epoch 10000: acc_real = 0.32, acc_fake = 0.74
# Epoch 12000: acc_real = 0.37, acc_fake = 0.52
# Epoch 12000: acc_real = 0.51, acc_fake = 0.62
